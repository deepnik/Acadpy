# %% [markdown]
# # Create a numpy array with 10 elements of the shape(10,1) using np.random and find out the mean of the elements using basic numpy functions.

# %%
import numpy as np

a=np.random.rand(10,1)
print(a)
print("mean=",a.mean())
# Out:
# [[0.81030847]
#  [0.63533788]
#  [0.74359769]
#  [0.33089072]
#  [0.57162007]
#  [0.71748054]
#  [0.22636521]
#  [0.63642264]
#  [0.96859536]
#  [0.03274556]]
# mean= 0.5673364144620826

# %% [markdown]
# # Create a numpy array with 20 elements of the shape(20,1) using np.random find the variance and standard deviation of the elements

# %%
import numpy as np

a=np.random.rand(20,1)
print(a)
print("standard deviation=",a.std())
print("variance=",a.var())
# Out:
# [[0.80272798]
#  [0.49549373]
#  [0.51073182]
#  [0.81108894]
#  [0.57001916]
#  [0.22130129]
#  [0.46015401]
#  [0.39109093]
#  [0.98860902]
#  [0.98839942]
#  [0.1185737 ]
#  [0.39937999]
#  [0.24510322]
#  [0.0418749 ]
#  [0.17352212]
#  [0.89311995]
#  [0.40361765]
#  [0.2021622 ]
#  [0.02199799]
#  [0.5555599 ]]
# standard deviation= 0.296490389538393
# variance= 0.08790655108862802

# %% [markdown]
# # Create a numpy array A of shape(10,20) and B of shape (20,25) using np.random. Print the matrix which is the matrix multiplication of A and B. The shape of the new matrix should be (10,25). Using basic numpy math functions only find the sum of all the elements of the new matrix.

# %%
import numpy as np
A=np.random.rand(10,20)
B=np.random.rand(20,25)
C=np.matmul(A,B)
print("new matrix C=",C)
print("")
print("")
print("shape of C=",C.shape)
print("sum of elements=",C.sum())
# Out:
# new matrix C= [[5.3934103  4.63633861 4.66434445 5.63637928 4.68050007 4.41485559
#   5.07017686 5.02207328 5.87238202 6.38463243 5.36737027 5.61098065
#   6.18596841 5.23451074 3.12924367 4.64428763 3.64934306 4.85752926
#   7.11083757 4.09177227 2.5747437  5.38867487 5.90908798 3.9163015
#   4.30881157]
#  [4.23180415 3.92745823 5.45363035 5.68584691 4.36588884 3.17058291
#   5.80954899 5.63429032 5.60943285 5.56303705 4.47579359 4.49696355
#   4.77130955 4.84253952 3.01709459 4.72184982 3.27576001 5.89199201
#   6.1988793  4.98282614 2.95312062 5.57439929 5.33835632 3.90619653
#   4.69206291]
#  [6.39738138 4.7193787  6.41960366 7.34726602 5.42076594 4.05968543
#   6.44406929 6.90564302 6.42762024 6.71391914 5.54009587 6.31953233
#   6.33401609 6.09776252 3.06189393 5.65632565 4.92876174 6.55215517
#   7.92054395 5.31260017 3.10034394 6.56528931 6.81428925 4.30281973
#   5.82308708]
#  [5.49271604 4.29976237 5.54236203 5.50914929 5.07886954 3.65453097
#   5.29081354 6.26898819 5.38690331 6.05133006 5.2668893  5.41945857
#   5.77423699 5.12429121 2.20315492 5.04232042 4.50844437 5.66197609
#   7.05914895 4.65423393 3.1219692  5.34167281 6.29163663 4.20449465
#   5.13441848]
#  [5.38612905 4.81666725 6.26489749 6.07605028 5.53444536 3.73288246
#   5.30942212 6.33193586 6.72530293 5.36114988 5.34297152 5.47344221
#   5.85755751 5.29349539 3.50058018 5.01435338 2.77372488 5.59725432
#   6.75300389 5.12536428 3.23254551 5.69276749 5.52366822 3.87228116
#   4.88406902]
#  [4.12201966 3.30682855 4.89660811 4.78902098 3.5458809  2.63189229
#   4.53754655 4.67555361 4.62150919 3.3955325  4.19178268 4.04472379
#   4.04598016 3.49731763 1.95253884 4.06696994 2.83803772 4.72500735
#   4.83324385 4.13951143 3.07359552 4.91055721 4.29616838 2.77458771
#   4.57159413]
#  [5.25119128 4.23477805 5.89481854 6.53259456 4.72781531 3.30491985
#   5.82521367 6.4131307  5.90237653 6.22350601 5.45635598 6.11042096
#   6.00137783 4.97062123 2.74695426 4.68713303 5.13021114 7.01468211
#   6.90477461 4.89834565 3.7125264  6.31235961 6.31968873 4.33231259
#   4.88356659]
#  [5.55680157 5.15587675 6.6347254  6.9710741  5.55616378 4.24513505
#   6.6767624  7.43388176 6.05796117 6.6550428  5.39801973 6.32595041
#   6.2064664  5.93978206 3.16954249 5.95021378 4.32862849 7.16917164
#   7.52821279 5.61329969 3.71075849 6.58511739 6.35247437 5.01182931
#   5.81295025]
#  [4.77819254 3.79943036 4.79140115 4.90547913 3.83615039 3.75679595
#   5.23965368 4.56498184 5.43718321 5.41946045 4.75429746 4.43568634
#   5.30231728 4.33894173 2.50405165 4.50959023 3.67756104 4.76294458
#   6.2684675  4.12192167 2.95901743 5.21340316 5.23926837 2.91455281
#   3.76718096]
#  [4.21915369 4.14816788 5.50759352 5.49810784 4.86754941 4.01819219
#   5.52356576 5.76962465 5.38464955 5.26262646 4.60475658 4.14343228
#   4.99401211 4.58061367 2.66107379 5.23759165 2.36269777 5.34449873
#   6.07156325 3.7160586  2.47182218 4.45862727 4.32144254 3.98120614
#   3.94937052]]
#
#
# shape of C= (10, 25)
# sum of elements= 1247.1072582598047

# %% [markdown]
# # Create a numpy array A of shape(10,1).Using the basic operations of the numpy array generate an array of shape(10,1) such that each element is the following function applied on each element of A.

# %%
import numpy as np
import math

A=np.random.rand(10,1)
#print(A)
l=[]
for x in A:
  for y in x:
    B=1 / (1 + math.exp(-y))
    l.append(B)
print(l)
# Out:
# [0.5180656841434277, 0.6120770438712191, 0.6818272400311154, 0.6608642357986926, 0.6385088786475605, 0.5989197271448617, 0.5791065979529687, 0.543991616963791, 0.5450104164235857, 0.6955579403297281]
